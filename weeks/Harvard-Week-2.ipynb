# %% [markdown]
# # Welcome to Python in CoCalc!
#
# Run a cell via `Shift + Return`. Learn more about [CoCalc Jupyter Notebooks](https://doc.cocalc.com/jupyter.html).

# %%
import matplotlib.pyplot as plt
plt.plot([0,1,4,9,16]);

# %%
plt.plot([0,1,2],[0,1,4],"rd-")

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First")
plt.plot(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("myplot.pdf")

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First")
plt.loglog(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("myplot.pdf")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:8: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:8: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
x = np.linspace(-1, 1, 40)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth = 2, markersize = 12, label = "First")
plt.plot(x, y2, "gs-", linewidth = 2, markersize = 12, label = "Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("myplot.pdf")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in power
#   app.launch_new_instance()

# %%
# generating histograms 2.3.4

import matplotlib.pyplot as plt

import numpy as np

x = np.random.normal(size=1000)

plt.hist(x);

# %%
plt.hist(x, normed=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-98d035d2c653> in <module>
# ----> 1 plt.hist(x, normed=True);
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
plt.hist(x, normed=True, bins=np.linspace(-5, 5, 21));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4b6ce4b819d5> in <module>
# ----> 1 plt.hist(x, normed=True, bins=np.linspace(-5, 5, 21));
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
x = np.random.gamma(2, 3, 100000)
plt.figure()
plt.subplot(221)
plt.hist(x, bins = 30)
plt.subplot(222)
plt.hist(x, bins = 30, normed = True)
plt.subplot(223)
plt.hist(x, bins = 30, cumulative = True)
plt.subplot(224)
plt.hist(x, bins = 30, normed = True, cumulative = True, histtype = "step")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9c34e24c4629> in <module>
#       4 plt.hist(x, bins = 30)
#       5 plt.subplot(222)
# ----> 6 plt.hist(x, bins = 30, normed = True)
#       7 plt.subplot(223)
#       8 plt.hist(x, bins = 30, cumulative = True)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
plt.hist(x, bins = 30)
# Out:
# (array([8.5360e+03, 1.6670e+04, 1.7299e+04, 1.4982e+04, 1.1876e+04,
#         8.9910e+03, 6.5340e+03, 4.7900e+03, 3.3520e+03, 2.2910e+03,
#         1.5370e+03, 1.0270e+03, 7.4800e+02, 4.7800e+02, 3.1200e+02,
#         2.0600e+02, 1.3600e+02, 8.8000e+01, 4.9000e+01, 2.9000e+01,
#         2.5000e+01, 1.6000e+01, 1.0000e+01, 5.0000e+00, 4.0000e+00,
#         2.0000e+00, 3.0000e+00, 0.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([1.25707193e-02, 1.45662687e+00, 2.90068303e+00, 4.34473918e+00,
#         5.78879533e+00, 7.23285148e+00, 8.67690764e+00, 1.01209638e+01,
#         1.15650199e+01, 1.30090761e+01, 1.44531322e+01, 1.58971884e+01,
#         1.73412446e+01, 1.87853007e+01, 2.02293569e+01, 2.16734130e+01,
#         2.31174692e+01, 2.45615253e+01, 2.60055815e+01, 2.74496376e+01,
#         2.88936938e+01, 3.03377499e+01, 3.17818061e+01, 3.32258622e+01,
#         3.46699184e+01, 3.61139745e+01, 3.75580307e+01, 3.90020868e+01,
#         4.04461430e+01, 4.18901992e+01, 4.33342553e+01]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(x, bins = 30, normed = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-3313bca8ec32> in <module>
# ----> 1 plt.hist(x, bins = 30, normed = True)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
plt.hist(x, bins = 30, cumulative = True)
# Out:
# (array([  8536.,  25206.,  42505.,  57487.,  69363.,  78354.,  84888.,
#          89678.,  93030.,  95321.,  96858.,  97885.,  98633.,  99111.,
#          99423.,  99629.,  99765.,  99853.,  99902.,  99931.,  99956.,
#          99972.,  99982.,  99987.,  99991.,  99993.,  99996.,  99996.,
#          99998., 100000.]),
#  array([1.25707193e-02, 1.45662687e+00, 2.90068303e+00, 4.34473918e+00,
#         5.78879533e+00, 7.23285148e+00, 8.67690764e+00, 1.01209638e+01,
#         1.15650199e+01, 1.30090761e+01, 1.44531322e+01, 1.58971884e+01,
#         1.73412446e+01, 1.87853007e+01, 2.02293569e+01, 2.16734130e+01,
#         2.31174692e+01, 2.45615253e+01, 2.60055815e+01, 2.74496376e+01,
#         2.88936938e+01, 3.03377499e+01, 3.17818061e+01, 3.32258622e+01,
#         3.46699184e+01, 3.61139745e+01, 3.75580307e+01, 3.90020868e+01,
#         4.04461430e+01, 4.18901992e+01, 4.33342553e+01]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(x, bins = 30, normed = True, cumulative = True, histtype = "step")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-cee1d1e7dae3> in <module>
# ----> 1 plt.hist(x, bins = 30, normed = True, cumulative = True, histtype = "step")
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
# simulating randomness - 2.4.1

import random

random.choice(["H", "T"])
# Out:
# 1

# %%
random.choice([1, 2, 3, 4, 5, 6])
# Out:
# 4

# %%
random.choice(range(1, 7))
# Out:
# 3

# %%
random.choice(random.choice([range(1, 7), range(1,9), range(1,11)]))
# Out:
# 6

# %%
random.choice(list([1,2,3,4]))
# Out:
# 4

# %%
sum(random.choice(range(10)) for i in range(10))
# Out:
# 48

# %%
# example involvinh randomness - 2.4.2

import random

rolls = []

# tried for 100, 10000 and 1000000
for k in range(1000000):
    rolls.append(random.choice([1,2,3,4,5,6]))

plt.hist(rolls, bins = np.linspace(0.5, 6.5, 7));

# %%
ys = []

for rep in range(1000000):
    y = 0
    for k in range(10):
        x = random.choice([1,2,3,4,5,6])
        y += x
    ys.append(y)

plt.hist(ys);

# %%
random.choice(list((1,2,3,4)))
# Out:
# 3

# %%
# using the numpy random module - 2.4.3

import numpy as np

np.random.random()
# Out:
# 0.9967020431221961

# %%
np.random.random(5)
# Out:
# array([0.03466871, 0.01975561, 0.68697075, 0.41133348, 0.76587567])

# %%
np.random.random((5,3))
# Out:
# array([[0.84600278, 0.39257299, 0.26948123],
#        [0.31874295, 0.46430341, 0.37365036],
#        [0.0440725 , 0.0638002 , 0.6368901 ],
#        [0.16142918, 0.8282687 , 0.60220882],
#        [0.13594133, 0.77951955, 0.24192606]])

# %%
np.random.normal(0, 1)
# Out:
# 1.0488232009312892

# %%
np.random.normal(0, 1, 5)
# Out:
# array([-0.27992919,  0.79783045,  0.41490911,  0.66903775, -2.19330802])

# %%
np.random.normal(0, 1, (2, 5))
# Out:
# array([[-0.43026742,  0.44806433, -0.90851716,  0.62493637,  0.36516166],
#        [ 0.1228112 ,  0.97721176,  0.13631411, -0.97448799,  0.41965044]])

# %%
np.random.randint(1,7)
# Out:
# 1

# %%
X = np.random.randint(1, 7, (10, 3))
X
# Out:
# array([[2, 5, 6],
#        [2, 6, 1],
#        [4, 2, 5],
#        [4, 1, 2],
#        [4, 2, 5],
#        [5, 3, 3],
#        [4, 3, 3],
#        [4, 6, 4],
#        [5, 6, 4],
#        [1, 2, 4]])

# %%
np.sum(X)
# Out:
# 108

# %%
np.sum(X, axis=0)
# Out:
# array([35, 36, 37])

# %%
np.sum(X, axis=1)
# Out:
# array([13,  9, 11,  7, 11, 11, 10, 14, 15,  7])

# %%
Y = np.sum(X, axis=1)
Y
# Out:
# array([13,  9, 11,  7, 11, 11, 10, 14, 15,  7])

# %%
X = np.random.randint(1, 7, (1000000, 10))
Y = np.sum(X, axis=1)
plt.hist(Y);

# numpy 10 times faster than python code

# %%
np.random.random((5, 2, 3))
# Out:
# array([[[0.616721  , 0.6177404 , 0.70456348],
#         [0.88972908, 0.07677931, 0.44389896]],
#
#        [[0.64753625, 0.98513785, 0.13067562],
#         [0.16311605, 0.64038074, 0.91446745]],
#
#        [[0.13634268, 0.07009736, 0.46153753],
#         [0.86896615, 0.69839182, 0.33798698]],
#
#        [[0.58026271, 0.13107454, 0.17777806],
#         [0.16971363, 0.28116724, 0.44464903]],
#
#        [[0.76107056, 0.610612  , 0.93639025],
#         [0.36742217, 0.49206529, 0.61650187]]])

# %%
np.random.normal(1, 2, 3)
# Out:
# array([5.85610817, 5.76697041, 2.19173954])

# %%
np.random.randint(1, 5, (2, 3))
# Out:
# array([[4, 1, 2],
#        [4, 1, 2]])

# %%
np.sum(np.random.randint(1,7,(100,10)), axis=0)
# Out:
# array([343, 361, 371, 357, 356, 369, 363, 364, 384, 342])

# %%
# measuring time - 2.4.4

import time

start_time = time.clock()

end_time = time.clock()

end_time-start_time
# Out:
# 0.0003140000000030341

# %%
# random walks - 2.4.5

X_0 = np.array([[0], [0]])

delta_X = np.random.normal(0, 1, (2, 10000))

X = np.concatenate((X_0, np.cumsum(delta_X, axis=1)), axis=1)

plt.plot(X[0], X[1], "ro-");
